# %%
from hf_model import HFModel

model = HFModel("gpt2")

out = model.generate(
    "What is the capital of France?",
    num_return_sequences=3
)

print(out.responses)
print(len(out.logits))
print(out.logits[0].shape)
print(out.log_probs)
# Out:
# Loading weights: 100%|██████████| 148/148 [00:00<00:00, 625.33it/s, Materializing param=transformer.wte.weight]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ["What is the capital of France? In Paris, France, you'll know it from its proximity to Milan, Paris to Milan and St. Peter's, but when they did the city lost its great capital.\n\nThe word capital refers to the Roman-European region of Italy.", 'What is the capital of France?\n\nThe capital lies in the country\'s west front.\n\nFrance has three provinces and the main capital is Paris. What is Paris?\n\nThere are three provinces and the provinces are:\n\nCyrillic — "the south', 'What is the capital of France? What is Paris? What is Marseille? What will become of the United States if only the political crisis that began in Paris had not been taken seriously? And what is the significance of these questions to President Obama? It is clear that the greatest political']
# 50
# torch.Size([3, 50257])
# [tensor([-4.2254, -0.7657, -3.3112]), tensor([-4.3392e+00, -3.1482e-03, -5.0169e-01]), tensor([-0.6060, -1.4270, -4.2032]), tensor([-3.0270, -0.2536, -0.5406]), tensor([-0.5796, -6.2590, -1.2936]), tensor([-3.2884, -0.7136, -0.3109]), tensor([-2.9009, -1.0024, -2.8301]), tensor([-4.4980, -3.3558, -0.0937]), tensor([-1.9388, -1.6492, -0.0609]), tensor([-2.6860, -4.2765, -0.9155]), tensor([-2.9681, -7.3543, -5.7124]), tensor([-5.4761, -1.1119, -3.1112]), tensor([-0.0489, -2.3324, -0.2960]), tensor([-5.4465e+00, -2.1598e-04, -1.2752e+00]), tensor([-1.5016, -1.8686, -4.0235]), tensor([-2.9862, -1.4529, -0.0824]), tensor([-3.7472, -3.3754, -2.7618]), tensor([-1.6021, -2.0173, -6.1053]), tensor([-2.3483, -3.2814, -1.6502]), tensor([-4.0131, -3.0006, -4.8156]), tensor([-0.0735, -3.9002, -5.2761]), tensor([-1.8320, -2.2608, -4.1127]), tensor([-0.1813, -0.8346, -2.6398]), tensor([-3.0841, -0.7620, -0.9013]), tensor([-3.9449, -0.3782, -3.0311]), tensor([-5.3176, -6.4726, -2.9208]), tensor([-4.9646, -0.8374, -1.2119]), tensor([-5.0907, -2.6288, -1.4250]), tensor([-1.6167, -0.4280, -4.8714]), tensor([-4.1859, -0.2833, -3.9812]), tensor([-5.2037e+00, -1.2051e-04, -8.6231e-01]), tensor([-0.5424, -4.2576, -3.0703]), tensor([-4.8273, -0.6450, -0.8975]), tensor([-2.8256, -0.6099, -1.6152]), tensor([-1.0358, -1.2629, -0.8882]), tensor([-1.2988, -2.7740, -3.3799]), tensor([-0.0015, -1.1081, -0.0373]), tensor([-1.7700, -7.1120, -3.6722]), tensor([-4.7911, -0.9175, -0.3019]), tensor([-0.5168, -1.3067, -2.3605]), tensor([-3.9186, -0.6143, -4.8816]), tensor([-7.1585e-02, -2.8451e-04, -1.7419e+00]), tensor([-0.6779, -3.6054, -0.7354]), tensor([-4.8795, -4.9303, -4.4246]), tensor([-5.2361, -1.8178, -0.4651]), tensor([-4.6898, -0.5295, -2.6140]), tensor([-4.8309, -4.1041, -0.3444]), tensor([-0.8842, -4.8042, -1.1617]), tensor([-2.7328, -1.6307, -5.1901]), tensor([-1.3207, -5.1331, -3.0409])]
